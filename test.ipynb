# %%
from population_functions import df,header

# %%
df.head()
# Out:
#           Rank CCA3 Country/Territory           Capital Continent  \
# Countries
# 0           36  AFG       Afghanistan             Kabul      Asia
# 1          138  ALB           Albania            Tirana    Europe
# 2           34  DZA           Algeria           Algiers    Africa
# 3          213  ASM    American Samoa         Pago Pago   Oceania
# 4          203  AND           Andorra  Andorra la Vella    Europe
#
#           2022 Population 2020 Population 2015 Population 2010 Population  \
# Countries
# 0                41128771        38972230        33753499        28189672
# 1                 2842321         2866849         2882481         2913399
# 2                44903225        43451666        39543154        35856344
# 3                   44273           46189           51368           54849
# 4                   79824           77700           71746           71519
#
#           2000 Population 1990 Population 1980 Population 1970 Population  \
# Countries
# ...

# %%
df.index.name="Countries"
df.columns.name="Header"

# %%
df.columns=header

# %%
df.head()
# Out:
#           Rank CCA3 Country/Territory           Capital Continent  \
# Countries
# 0           36  AFG       Afghanistan             Kabul      Asia
# 1          138  ALB           Albania            Tirana    Europe
# 2           34  DZA           Algeria           Algiers    Africa
# 3          213  ASM    American Samoa         Pago Pago   Oceania
# 4          203  AND           Andorra  Andorra la Vella    Europe
#
#           2022 Population 2020 Population 2015 Population 2010 Population  \
# Countries
# 0                41128771        38972230        33753499        28189672
# 1                 2842321         2866849         2882481         2913399
# 2                44903225        43451666        39543154        35856344
# 3                   44273           46189           51368           54849
# 4                   79824           77700           71746           71519
#
#           2000 Population 1990 Population 1980 Population 1970 Population  \
# Countries
# ...

# %%
df2=df.copy()

# %%
header
# Out:
# ['Rank',
#  'CCA3',
#  'Country/Territory',
#  'Capital',
#  'Continent',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population',
#  '2010 Population',
#  '2000 Population',
#  '1990 Population',
#  '1980 Population',
#  '1970 Population',
#  'Area (km²)',
#  'Density (per km²)',
#  'Growth Rate',
#  'World Population Percentage']

# %%
new_header=['Rank',
 'CCA3',
 'Country/Territory',
 'Capital',
 'Continent',
 'World Population Percentage',
 '2022 Population',
 '2020 Population',
 '2015 Population',
 '2010 Population',
 '2000 Population',
 '1990 Population',
 '1980 Population',
 '1970 Population',
 'Area (km²)',
 'Density (per km²)',
 'Growth Rate']

# %%
import pandas as pd
df2=pd.DataFrame(df2,columns=new_header)

# %%
df2.head()
# Out:
#           Rank CCA3 Country/Territory           Capital Continent  \
# Countries
# 0           36  AFG       Afghanistan             Kabul      Asia
# 1          138  ALB           Albania            Tirana    Europe
# 2           34  DZA           Algeria           Algiers    Africa
# 3          213  ASM    American Samoa         Pago Pago   Oceania
# 4          203  AND           Andorra  Andorra la Vella    Europe
#
#           World Population Percentage 2022 Population 2020 Population  \
# Countries
# 0                                0.52        41128771        38972230
# 1                                0.04         2842321         2866849
# 2                                0.56        44903225        43451666
# 3                                   0           44273           46189
# 4                                   0           79824           77700
#
#           2015 Population 2010 Population 2000 Population 1990 Population  \
# Countries
# ...

# %%
import numpy as np
df2["positive_growth_rate"]=np.where(df2["Growth Rate"].values.astype(np.float64)>1,True,False)

# %%
df_positive=df2[df2["positive_growth_rate"]]

# %%
df_positive[df_positive["Continent"]=="Europe"]
# Out:
#           Rank CCA3 Country/Territory           Capital Continent  \
# Countries
# 4          203  AND           Andorra  Andorra la Vella    Europe
# 12          99  AUT           Austria            Vienna    Europe
# 19          81  BEL           Belgium          Brussels    Europe
# 49         158  CYP            Cyprus           Nicosia    Europe
# 51         115  DNK           Denmark        Copenhagen    Europe
# 65         209  FRO     Faroe Islands          Tórshavn    Europe
# 67         118  FIN           Finland          Helsinki    Europe
# 68          23  FRA            France             Paris    Europe
# 83         207  GGY          Guernsey  Saint Peter Port    Europe
# 90          94  HUN           Hungary          Budapest    Europe
# 91         179  ISL           Iceland         Reykjavík    Europe
# 96         125  IRL           Ireland            Dublin    Europe
# 97         202  IMN       Isle of Man           Douglas    Europe
# ...

# %%
df_positive.loc[4]
# Out:
# Rank                                        203
# CCA3                                        AND
# Country/Territory                       Andorra
# Capital                        Andorra la Vella
# Continent                                Europe
# World Population Percentage                   0
# 2022 Population                           79824
# 2020 Population                           77700
# 2015 Population                           71746
# 2010 Population                           71519
# 2000 Population                           66097
# 1990 Population                           53569
# 1980 Population                           35611
# 1970 Population                           19860
# Area (km²)                                  468
# Density (per km²)                      170.5641
# Growth Rate                                1.01
# positive_growth_rate                       True
# Name: 4, dtype: object

# %%
df2.head()
# Out:
#           Rank CCA3 Country/Territory           Capital Continent  \
# Countries
# 0           36  AFG       Afghanistan             Kabul      Asia
# 1          138  ALB           Albania            Tirana    Europe
# 2           34  DZA           Algeria           Algiers    Africa
# 3          213  ASM    American Samoa         Pago Pago   Oceania
# 4          203  AND           Andorra  Andorra la Vella    Europe
#
#           World Population Percentage 2022 Population 2020 Population  \
# Countries
# 0                                0.52        41128771        38972230
# 1                                0.04         2842321         2866849
# 2                                0.56        44903225        43451666
# 3                                   0           44273           46189
# 4                                   0           79824           77700
#
#           2015 Population 2010 Population 2000 Population 1990 Population  \
# Countries
# ...

# %%
df2[df2["Country/Territory"]=="Canada"]
# Out:
#           Rank CCA3 Country/Territory Capital      Continent  \
# Countries
# 35          39  CAN            Canada  Ottawa  North America
#
#           World Population Percentage 2022 Population 2020 Population  \
# Countries
# 35                               0.48        38454327        37888705
#
#           2015 Population 2010 Population 2000 Population 1990 Population  \
# Countries
# 35               35732126        33963412        30683313        27657204
#
#           1980 Population 1970 Population Area (km²) Density (per km²)  \
# Countries
# 35               24511510        21434577    9984670            3.8513
#
#           Growth Rate  positive_growth_rate
# Countries
# 35             1.0078                  True
