# %% [markdown]
# # World Population Analysis
#
# Here we are going to analyze world population data:

# %% [markdown]
# ## Basic
#
# First imports:

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# Data importing:

# %%
df=pd.read_csv("./world_population.csv")
df.columns.name="Header"
df.index.name="Countries"

# %%
df.head()
# Out:
# Header     Rank CCA3 Country/Territory           Capital Continent  \
# Countries
# 0            36  AFG       Afghanistan             Kabul      Asia
# 1           138  ALB           Albania            Tirana    Europe
# 2            34  DZA           Algeria           Algiers    Africa
# 3           213  ASM    American Samoa         Pago Pago   Oceania
# 4           203  AND           Andorra  Andorra la Vella    Europe
#
# Header     2022 Population  2020 Population  2015 Population  2010 Population  \
# Countries
# 0                 41128771         38972230         33753499         28189672
# 1                  2842321          2866849          2882481          2913399
# 2                 44903225         43451666         39543154         35856344
# 3                    44273            46189            51368            54849
# 4                    79824            77700            71746            71519
#
# ...

# %% [markdown]
# ## Africa
#
# Let's start our analysis with Africa. First we create an african countries DataFrame:

# %%
df_africa=df[df["Continent"]=="Africa"]

# %%
df_africa.head()
# Out:
# Header     Rank CCA3 Country/Territory      Capital Continent  \
# Countries
# 2            34  DZA           Algeria      Algiers    Africa
# 5            42  AGO            Angola       Luanda    Africa
# 21           77  BEN             Benin   Porto-Novo    Africa
# 26          144  BWA          Botswana     Gaborone    Africa
# 31           58  BFA      Burkina Faso  Ouagadougou    Africa
#
# Header     2022 Population  2020 Population  2015 Population  2010 Population  \
# Countries
# 2                 44903225         43451666         39543154         35856344
# 5                 35588987         33428485         28127721         23364185
# 21                13352864         12643123         10932783          9445710
# 26                 2630296          2546402          2305171          2091664
# 31                22673762         21522626         18718019         16116845
#
# Header     2000 Population  1990 Population  1980 Population  1970 Population  \
# Countries
# ...

# %% [markdown]
# Let's start making questions. Are there countries in Africa within the top 10 more populated countries in the world?

# %%
(df_africa["Rank"].astype(np.int64)<=10).any()
# Out:
# True

# %% [markdown]
# Which are them?

# %%
df_africa[df_africa["Rank"].astype(np.int64)<=10]
# Out:
# Header     Rank CCA3 Country/Territory Capital Continent  2022 Population  \
# Countries
# 149           6  NGA           Nigeria   Abuja    Africa        218541212
#
# Header     2020 Population  2015 Population  2010 Population  2000 Population  \
# Countries
# 149              208327405        183995785        160952853        122851984
#
# Header     1990 Population  1980 Population  1970 Population  Area (km²)  \
# Countries
# 149               95214257         72951439         55569264      923768
#
# Header     Density (per km²)  Growth Rate  World Population Percentage
# Countries
# 149                 236.5759       1.0241                         2.74

# %% [markdown]
# Are there countries in Africa with a growth rate lower than 1? Which?

# %%
(df_africa["Growth Rate"].astype(np.float64)<1).any()
# Out:
# False

# %% [markdown]
# What's South Africa's capital city?

# %%
df_africa[df_africa["Country/Territory"]=="South Africa"]["Capital"].values[0]
# Out:
# 'Pretoria'

# %% [markdown]
# ## Oceania

# %%
df_oceania=df[df["Continent"]=="Oceania"]
df_oceania.index=np.arange(1,len(df_oceania)+1)

# %%
df_oceania.head()
# Out:
# Header  Rank CCA3 Country/Territory    Capital Continent  2022 Population  \
# 1        213  ASM    American Samoa  Pago Pago   Oceania            44273
# 2         55  AUS         Australia   Canberra   Oceania         26177413
# 3        223  COK      Cook Islands     Avarua   Oceania            17011
# 4        162  FJI              Fiji       Suva   Oceania           929766
# 5        183  PYF  French Polynesia    Papeete   Oceania           306279
#
# Header  2020 Population  2015 Population  2010 Population  2000 Population  \
# 1                 46189            51368            54849            58230
# 2              25670051         23820236         22019168         19017963
# 3                 17029            17695            17212            15897
# 4                920422           917200           905169           832509
# 5                301920           291787           283788           250927
#
# ...

# %% [markdown]
# How many countries are there in Oceania?

# %%
len(df_oceania)
# Out:
# 23
